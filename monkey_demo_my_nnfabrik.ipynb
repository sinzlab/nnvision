# %% [markdown]
# ## Example Notebook

# %% [markdown]
# ### Requirements

# %% [markdown]
# - nnfabrik, neuralpredictors, and nnvision from the sinzlab repository have to be installed/cloned
#
# - we are using the pytorch image called `sinzlab/pytorch:v3.8-torch1.4.0-cuda10.1-dj0.12.4`
#     - docker image can be found here: https://github.com/sinzlab/pytorch-docker or https://hub.docker.com/r/sinzlab/pytorch/dockerfile
#     - there, the complete list of packages to be installed can be found.
#     - torch >= 1.4 is required.
# </br>
# </br>
# - All individual pickle files and the image-pickle file have to be present. The can be found on the GPU server under /var/lib/nova/sinz-shared/data

# %% [markdown]
# # Imports

# %% [markdown]
# make sure to install all required packages. dependencies are listed in the dockerfile above. If necessary, install packages within the environment

# %%
import datajoint as dj
import os

dj.config['enable_python_native_blobs'] = True
dj.config['nnfabrik.schema_name'] = "mburg_nnvision_monkey_demo"

dj.config["display.limit"] = 50
# set external store based on env vars
if "stores" not in dj.config:
    dj.config["stores"] = {}
dj.config["stores"]["minio"] = {  # store in s3
    "protocol": "s3",
    "endpoint": os.environ.get("MINIO_ENDPOINT", "DUMMY_ENDPOINT"),
    "bucket": "nnfabrik",
    "location": "dj-store",
    "access_key": os.environ.get("MINIO_ACCESS_KEY", "FAKEKEY"),
    "secret_key": os.environ.get("MINIO_SECRET_KEY", "FAKEKEY"),
}

from nnfabrik.main import my_nnfabrik
my_nnf = my_nnfabrik("mburg_nnvision_monkey_demo", use_common_fabrikant=False, use_common_seed=False)

from nnfabrik.utility.dj_helpers import CustomSchema
schema = CustomSchema(dj.config.get("nnfabrik.schema_name", "mburg_nnvision_monkey_demo"))

from nnfabrik.templates.trained_model import TrainedModelBase
from nnfabrik.main import *
# Out:
# Connecting mburg@134.2.168.16:3306

# %%
from os import listdir
from os.path import isfile, join

import matplotlib.pyplot as plt
import numpy as np

from nnfabrik import builder

# %% [markdown]
# # NNfabrik intro: Using the builder to build the dataloader objects, models, trainer

# %%
# here's where the data is on the server:
os.listdir('/data')
# Out:
# ['temp',
#  'mouse',
#  'monkey',
#  'ivan-celltype-clustering',
#  'monkey-cadena-ploscb-2019']

# %%
#### loading monkey data

basepath = '/data/monkey/toliaslab/CSRF19_V1'
neuronal_data_path = os.path.join(basepath, 'neuronal_data/')
neuronal_data_files = [neuronal_data_path+f for f in listdir(neuronal_data_path) if isfile(join(neuronal_data_path, f))]
image_file = os.path.join(basepath, 'images/CSRF19_V1_images.pickle')
image_cache_path = os.path.join(basepath, 'images/individual')

# %%
# Specifying the dataset function: its defined in nnvision/datasets, and has to present in the __init__.py there.
dataset_fn = 'nnvision.datasets.monkey_static_loader'
dataset_config = dict(dataset='CSRF19_V1',
                               neuronal_data_files=neuronal_data_files,
                               image_cache_path=image_cache_path,
                               crop=102,
                               subsample=1,
                               seed=1000,
                               time_bins_sum=6,
                               batch_size=128,)

# %%
dataloaders = builder.get_data(dataset_fn, dataset_config)

# %% [markdown]
# ## Dataloaders

# %% [markdown]
# NNfabrik expects dataloaders to be nested dictionarys with actual PyTorch DataLoader Objects at the second Tier. The First Tier will be "train", "validation", and "test". The second Tier will be "session_key": DataLoader. So each dataset is either comprised of one or multiple sessions, with a session ID as the dictionary key to its dataloader.
# Let's have a look:

# %%
dataloaders
# Out:
# {'train': {'3637161140869': <torch.utils.data.dataloader.DataLoader at 0x7fbc151a6160>,
#   '3638885582960': <torch.utils.data.dataloader.DataLoader at 0x7fbaec3f7070>,
#   '3636034866307': <torch.utils.data.dataloader.DataLoader at 0x7fbaec3f7e20>,
#   '3637760318484': <torch.utils.data.dataloader.DataLoader at 0x7fbaec3fbd00>,
#   '3631896544452': <torch.utils.data.dataloader.DataLoader at 0x7fbaec400be0>,
#   '3639749909659': <torch.utils.data.dataloader.DataLoader at 0x7fbaec404a60>,
#   '3634658447291': <torch.utils.data.dataloader.DataLoader at 0x7fbaec406940>,
#   '3638456653849': <torch.utils.data.dataloader.DataLoader at 0x7fbaec40b820>,
#   '3639492658943': <torch.utils.data.dataloader.DataLoader at 0x7fbaec40f700>,
#   '3635949043110': <torch.utils.data.dataloader.DataLoader at 0x7fbaec413580>,
#   '3639406161189': <torch.utils.data.dataloader.DataLoader at 0x7fbaec415460>,
#   '3634055946316': <torch.utils.data.dataloader.DataLoader at 0x7fbaec41a340>,
#   '3631807112901': <torch.utils.data.dataloader.DataLoader at 0x7fbaec41d1f0>,
#   '3635178040531': <torch.utils.data.dataloader.DataLoader at 0x7fbaec4220d0>,
#   '3638802601378': <torch.utils.data.dataloader.DataLoader at 0x7fbaec422e50>,
#   '3638541006102': <torch.utils.data.dataloader.DataLoader at 0x7fbaec427f40>,
#   '3640011636703': <torch.utils.data.dataloader.DataLoader at 0x7fbaec42ce20>,
#   '3639664527524': <torch.utils.data.dataloader.DataLoader at 0x7fbaec42fd00>,
#   '3638367026975': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef06be0>,
#   '3638373332053': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef0aa60>,
#   '3634744023164': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef0e940>,
#   '3638973674012': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef12820>,
#   '3632669014376': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef16700>,
#   '3640095265572': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef1a580>,
#   '3637248451650': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef1d460>,
#   '3639060843972': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef21340>,
#   '3636552742293': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef241f0>,
#   '3633364677437': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef290d0>,
#   '3637851724731': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef29e50>,
#   '3634142311627': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef2df40>,
#   '3637333931598': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef32e20>,
#   '3632932714885': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef35d00>},
#  'validation': {'3637161140869': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef5e880>,
#   '3638885582960': <torch.utils.data.dataloader.DataLoader at 0x7fbaec3f74f0>,
#   '3636034866307': <torch.utils.data.dataloader.DataLoader at 0x7fbaec3fb3d0>,
#   '3637760318484': <torch.utils.data.dataloader.DataLoader at 0x7fbaec4002b0>,
#   '3631896544452': <torch.utils.data.dataloader.DataLoader at 0x7fbaec404160>,
#   '3639749909659': <torch.utils.data.dataloader.DataLoader at 0x7fbaec406040>,
#   '3634658447291': <torch.utils.data.dataloader.DataLoader at 0x7fbaec406fa0>,
#   '3638456653849': <torch.utils.data.dataloader.DataLoader at 0x7fbaec40be80>,
#   '3639492658943': <torch.utils.data.dataloader.DataLoader at 0x7fbaec40fd60>,
#   '3635949043110': <torch.utils.data.dataloader.DataLoader at 0x7fbaec413be0>,
#   '3639406161189': <torch.utils.data.dataloader.DataLoader at 0x7fbaec415ac0>,
#   '3634055946316': <torch.utils.data.dataloader.DataLoader at 0x7fbaec41a9a0>,
#   '3631807112901': <torch.utils.data.dataloader.DataLoader at 0x7fbaec41d850>,
#   '3635178040531': <torch.utils.data.dataloader.DataLoader at 0x7fbaec422730>,
#   '3638802601378': <torch.utils.data.dataloader.DataLoader at 0x7fbaec427610>,
#   '3638541006102': <torch.utils.data.dataloader.DataLoader at 0x7fbaec42c4f0>,
#   '3640011636703': <torch.utils.data.dataloader.DataLoader at 0x7fbaec42f3d0>,
#   '3639664527524': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef062b0>,
#   '3638367026975': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef0a160>,
#   '3638373332053': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef0e040>,
#   '3634744023164': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef0efa0>,
#   '3638973674012': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef12e80>,
#   '3632669014376': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef16d60>,
#   '3640095265572': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef1abe0>,
#   '3637248451650': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef1dac0>,
#   '3639060843972': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef219a0>,
#   '3636552742293': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef24850>,
#   '3633364677437': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef29730>,
#   '3637851724731': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef2d610>,
#   '3634142311627': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef324f0>,
#   '3637333931598': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef353d0>,
#   '3632932714885': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef3a2b0>},
#  'test': {'3637161140869': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef5e850>,
#   '3638885582960': <torch.utils.data.dataloader.DataLoader at 0x7fbaec3f7c70>,
#   '3636034866307': <torch.utils.data.dataloader.DataLoader at 0x7fbaec3fbb50>,
#   '3637760318484': <torch.utils.data.dataloader.DataLoader at 0x7fbaec400a30>,
#   '3631896544452': <torch.utils.data.dataloader.DataLoader at 0x7fbaec4048e0>,
#   '3639749909659': <torch.utils.data.dataloader.DataLoader at 0x7fbaec4067c0>,
#   '3634658447291': <torch.utils.data.dataloader.DataLoader at 0x7fbaec40b6a0>,
#   '3638456653849': <torch.utils.data.dataloader.DataLoader at 0x7fbaec40f580>,
#   '3639492658943': <torch.utils.data.dataloader.DataLoader at 0x7fbaec413400>,
#   '3635949043110': <torch.utils.data.dataloader.DataLoader at 0x7fbaec4152e0>,
#   '3639406161189': <torch.utils.data.dataloader.DataLoader at 0x7fbaec41a1c0>,
#   '3634055946316': <torch.utils.data.dataloader.DataLoader at 0x7fbaec41d0d0>,
#   '3631807112901': <torch.utils.data.dataloader.DataLoader at 0x7fbaec41dfd0>,
#   '3635178040531': <torch.utils.data.dataloader.DataLoader at 0x7fbaec422eb0>,
#   '3638802601378': <torch.utils.data.dataloader.DataLoader at 0x7fbaec427d90>,
#   '3638541006102': <torch.utils.data.dataloader.DataLoader at 0x7fbaec42cc70>,
#   '3640011636703': <torch.utils.data.dataloader.DataLoader at 0x7fbaec42fb50>,
#   '3639664527524': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef06a30>,
#   '3638367026975': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef0a8e0>,
#   '3638373332053': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef0e7c0>,
#   '3634744023164': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef126a0>,
#   '3638973674012': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef16580>,
#   '3632669014376': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef1a400>,
#   '3640095265572': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef1d2e0>,
#   '3637248451650': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef211c0>,
#   '3639060843972': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef240d0>,
#   '3636552742293': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef24fd0>,
#   '3633364677437': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef29eb0>,
#   '3637851724731': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef2dd90>,
#   '3634142311627': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef32c70>,
#   '3637333931598': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef35b50>,
#   '3632932714885': <torch.utils.data.dataloader.DataLoader at 0x7fbaeef3aa30>}}

# %%
# here's a random image. The images are cropped to be 20x20, so it trains fast for demo purposes.
some_image = dataloaders["train"][list(dataloaders["train"].keys())[0]].dataset[:].inputs[0,0,::].cpu().numpy()
plt.imshow(some_image, cmap='gray')

# %%
# get first data_key
first_session_ID = list((dataloaders["train"].keys()))[0]

# %%
a_dataloader = dataloaders["train"][first_session_ID]
a_dataloader

# %%
inputs, targets = next(iter(a_dataloader))
print("image_dimensions:", inputs.shape)
print("number of neurons of that session: ", targets.shape)
print("total training batches: ", len(a_dataloader))
# Out:
# image_dimensions: torch.Size([128, 1, 29, 29])
# number of neurons of that session:  torch.Size([128, 22])
# total training batches:  76

# %%
# input image dimension
input_shape = dataloaders["train"][first_session_ID].dataset[:].inputs.shape
print(input_shape)
# total images = 16064
# dims: N x C x W x H
# Out:
# torch.Size([9683, 1, 29, 29])

# %%
# outpt dimensions: neuronal firing rates'
output_shape = dataloaders["train"][first_session_ID].dataset[:].targets.shape

print(output_shape)
# Output: 14 Neurons, with N spikes over 60 ms
# Out:
# torch.Size([9683, 22])

# %% [markdown]
# ## Model Building

# %% [markdown]
# Models are built using the neuralpredictors repo from sinzlab. They consist of a convolutional core (with a user-specified number of layers), and a readout (spatial transformer readout, described in Sinz et al, 2018, NeurIPS).

# %% [markdown]
# ### Building a model

# %%
model_fn = 'nnvision.models.se_core_full_gauss_readout'
model_config = {'pad_input': False,
                'stack': -1,
               'depth_separable': True,
               'input_kern': 20,
               'gamma_input': 11.2,
               'gamma_readout': 0.33,
               'hidden_dilation': 1,
               'hidden_kern': 5,
               'n_se_blocks': 0,
               'hidden_channels': 32}
model = builder.get_model(model_fn, model_config, dataloaders=dataloaders,seed=1000)
print(model)
# Out:
# Encoder(
#   (core): SE2dCore(
#     (_input_weights_regularizer): LaplaceL2norm(
#       (laplace): Laplace()
#     )
#     (features): Sequential(
#       (layer0): Sequential(
#         (conv): Conv2d(1, 32, kernel_size=(20, 20), stride=(1, 1), bias=False)
#         (norm): BatchNorm2d(32, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (layer1): Sequential(
#         (ds_conv): DepthSeparableConv2d(
#           (in_depth_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (spatial_conv): Conv2d(32, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=32, bias=False)
#           (out_depth_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (norm): BatchNorm2d(32, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (layer2): Sequential(
#         (ds_conv): DepthSeparableConv2d(
#           (in_depth_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (spatial_conv): Conv2d(32, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=32, bias=False)
#           (out_depth_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (norm): BatchNorm2d(32, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#     )
#   ) [SE2dCore regularizers: gamma_input = 11.2|skip = 0]
#
#   (readout): MultipleFullGaussian2d(
#     (3637161140869): full FullGaussian2d (32 x 10 x 10 -> 22) with bias
#     (3638885582960): full FullGaussian2d (32 x 10 x 10 -> 5) with bias
#     (3636034866307): full FullGaussian2d (32 x 10 x 10 -> 20) with bias
#     (3637760318484): full FullGaussian2d (32 x 10 x 10 -> 20) with bias
#     (3631896544452): full FullGaussian2d (32 x 10 x 10 -> 32) with bias
#     (3639749909659): full FullGaussian2d (32 x 10 x 10 -> 8) with bias
#     (3634658447291): full FullGaussian2d (32 x 10 x 10 -> 5) with bias
#     (3638456653849): full FullGaussian2d (32 x 10 x 10 -> 2) with bias
#     (3639492658943): full FullGaussian2d (32 x 10 x 10 -> 17) with bias
#     (3635949043110): full FullGaussian2d (32 x 10 x 10 -> 10) with bias
#     (3639406161189): full FullGaussian2d (32 x 10 x 10 -> 14) with bias
#     (3634055946316): full FullGaussian2d (32 x 10 x 10 -> 21) with bias
#     (3631807112901): full FullGaussian2d (32 x 10 x 10 -> 29) with bias
#     (3635178040531): full FullGaussian2d (32 x 10 x 10 -> 6) with bias
#     (3638802601378): full FullGaussian2d (32 x 10 x 10 -> 7) with bias
#     (3638541006102): full FullGaussian2d (32 x 10 x 10 -> 17) with bias
#     (3640011636703): full FullGaussian2d (32 x 10 x 10 -> 2) with bias
#     (3639664527524): full FullGaussian2d (32 x 10 x 10 -> 18) with bias
#     (3638367026975): full FullGaussian2d (32 x 10 x 10 -> 16) with bias
#     (3638373332053): full FullGaussian2d (32 x 10 x 10 -> 10) with bias
#     (3634744023164): full FullGaussian2d (32 x 10 x 10 -> 12) with bias
#     (3638973674012): full FullGaussian2d (32 x 10 x 10 -> 18) with bias
#     (3632669014376): full FullGaussian2d (32 x 10 x 10 -> 21) with bias
#     (3640095265572): full FullGaussian2d (32 x 10 x 10 -> 25) with bias
#     (3637248451650): full FullGaussian2d (32 x 10 x 10 -> 7) with bias
#     (3639060843972): full FullGaussian2d (32 x 10 x 10 -> 12) with bias
#     (3636552742293): full FullGaussian2d (32 x 10 x 10 -> 24) with bias
#     (3633364677437): full FullGaussian2d (32 x 10 x 10 -> 10) with bias
#     (3637851724731): full FullGaussian2d (32 x 10 x 10 -> 14) with bias
#     (3634142311627): full FullGaussian2d (32 x 10 x 10 -> 14) with bias
#     (3637333931598): full FullGaussian2d (32 x 10 x 10 -> 9) with bias
#     (3632932714885): full FullGaussian2d (32 x 10 x 10 -> 11) with bias
#   )
# )

# %% [markdown]
# Above is the model description. Each session has its own readout. The Readout learns an x,y position between -1 and 1, relative to image space, and reads out from that point in feature space. THat means that the effective receptive field size of a unit in the last hidden layer will also be the receptive field size of the neuron. The x/y coordinates can be accessed like this:

# %%
model.core.features.layer0.conv.weight.data.shape
# Out:
# torch.Size([32, 1, 20, 20])

# %% [markdown]
# #### Show example readout positions after initialization

# %%
# x/y position (after random initialization, becuse the model isnt trained yet) for each neuron in that session
model.readout[first_session_ID].grid
# Out:
# tensor([[[[-0.1017, -0.1422]],
#
#          [[ 0.1074, -0.0624]],
#
#          [[-0.0140, -0.1852]],
#
#          [[-0.0939,  0.1339]],
#
#          [[ 0.1270, -0.0854]],
#
#          [[ 0.0903, -0.1766]],
#
#          [[ 0.1376, -0.0156]],
#
#          [[-0.0767,  0.1409]],
#
#          [[ 0.1300,  0.0866]],
#
#          [[ 0.0717,  0.1135]],
#
#          [[-0.0119, -0.1061]],
#
#          [[ 0.1604, -0.0997]],
#
#          [[ 0.0196, -0.1664]],
#
#          [[ 0.0189,  0.1813]],
#
#          [[-0.1017,  0.0104]],
#
#          [[ 0.1327,  0.0214]],
#
#          [[-0.0400, -0.1720]],
#
#          [[-0.1821,  0.0498]],
#
#          [[ 0.0327, -0.1954]],
#
#          [[-0.1747,  0.0716]],
#
#          [[ 0.1302,  0.1117]],
#
#          [[-0.1723,  0.0734]]]], grad_fn=<ClampBackward1>)

# %% [markdown]
# ## Building a Trainer

# %% [markdown]
# the trainer is taking care of the whole training process. when the trainer is built, itÄ's a function with the configuration already initialized

# %%
trainer_fn = 'nnvision.training.nnvision_trainer'
trainer_config = dict(max_iter=1, 
                      lr_decay_steps=4, 
                      tolerance=0.0005, 
                      patience=5,
                      verbose=False, 
                      lr_init=0.003,
                      avg_loss=False,
                      device='cuda')

trainer = builder.get_trainer(trainer_fn, trainer_config)

# %% [markdown]
# ## Train a model

# %%
score, output, model_state = trainer(model=model, dataloaders=dataloaders, seed=1000)
# Out:
# Epoch 1: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 3616/3616 [00:34<00:00, 104.64it/s]
# [001|00/05] ---> 0.21212442219257355
# Restoring best model! 0.212124 ---> 0.212124

# %% [markdown]
# # Part Two: NNfabrik and DataJoint

# %% [markdown]
# Instead of using the builder to get the data/model/and trainer, we can use datajoint to manage that process for us.
# There are Model, Dataset, and Trainer Tables. And each combination in those tables should in principle lead to a fully trained model.
# For completeness, there is also a Seed table that stores the random seed, and a Fabrikant table, that stores the name and contact details of the creator (=Fabrikant).

# %%
my_nnf.Fabrikant()
# Out:
# *fabrikant_nam full_name     email     affiliation    dj_username
# +------------+ +-----------+ +-------+ +------------+ +------------+
#
#  (Total: 0)

# %%
# change this entry to reflect your datajoint username
my_nnf.Fabrikant().insert1(dict(fabrikant_name='mburg',
                         email="first.last@uni-goettingen.de",
                         affiliation='eckerlab',
                         dj_username="mburg"))

# %%
my_nnf.Fabrikant()
# Out:
# *fabrikant_nam full_name     email          affiliation    dj_username
# +------------+ +-----------+ +------------+ +------------+ +------------+
# mburg                        first.last@uni eckerlab       mburg
#  (Total: 1)

# %%
my_nnf.Seed().insert([{'seed':1000}])
my_nnf.Seed()
# Out:
# *seed
# +------+
# 1000
#  (Total: 1)

# %% [markdown]
# ###  add entries for dataset, model, and trainer, with their corresponding configurations

# %% [markdown]
# #### Dataset

# %%
# adds the dataset_function and dataset config that we defined above to the datase table
my_nnf.Dataset().add_entry(dataset_fn, dataset_config, dataset_comment='CSRF_V1', dataset_fabrikant='mburg')
my_nnf.Dataset()
# Out:
# *dataset_fn    *dataset_hash  dataset_co dataset_fabrik dataset_commen dataset_ts
# +------------+ +------------+ +--------+ +------------+ +------------+ +------------+
# nnvision.datas 011a0f520e4393 =BLOB=     mburg          CSRF_V1        2021-08-25 09:
#  (Total: 1)

# %% [markdown]
# #### Model

# %%
model_fn = 'nnvision.models.se_core_full_gauss_readout'
model_config = {'pad_input': False,
                'stack': -1,
               'depth_separable': True,
               'input_kern': 20,
               'gamma_input': 11.2,
               'gamma_readout': 0.33,
               'hidden_dilation': 1,
               'hidden_kern': 5,
               'n_se_blocks': 0,
               'hidden_channels': 32,
               'gauss_type': 'isotropic'}                
my_nnf.Model().add_entry(model_fn, model_config, model_comment='isotropic', model_fabrikant='mburg')
my_nnf.Model()
# Out:
# *model_fn      *model_hash    model_conf model_fabrikan model_comment  model_ts
# +------------+ +------------+ +--------+ +------------+ +------------+ +------------+
# nnvision.model a08c72eb297205 =BLOB=     mburg          isotropic      2021-08-25 09:
#  (Total: 1)

# %%
my_nnf.Trainer.delete()
# Out:
# About to delete:
# Nothing to delete

# %%
trainer_fn = 'nnvision.training.nnvision_trainer'
trainer_config = dict(max_iter=2, 
                      lr_decay_steps=4, 
                      tolerance=0.0005, 
                      patience=5,
                      verbose=False, 
                      lr_init=0.0045,
                      avg_loss=False,
                      device='cuda')

my_nnf.Trainer().add_entry(trainer_fn, trainer_config, trainer_comment="max_iter: 2", trainer_fabrikant='mburg')
my_nnf.Trainer()
# Out:
# *trainer_fn    *trainer_hash  trainer_co trainer_fabrik trainer_commen trainer_ts
# +------------+ +------------+ +--------+ +------------+ +------------+ +------------+
# nnvision.train e225a557fe8039 =BLOB=     mburg          max_iter: 2    2021-08-25 09:
#  (Total: 1)

# %%
(my_nnf.Trainer&"trainer_hash='e225a557fe8039df3717ddbe4686caa9'")
# Out:
# *trainer_fn    *trainer_hash  trainer_co trainer_fabrik trainer_commen trainer_ts
# +------------+ +------------+ +--------+ +------------+ +------------+ +------------+
# nnvision.train e225a557fe8039 =BLOB=     mburg          max_iter: 2    2021-08-25 09:
#  (Total: 1)

# %% [markdown]
# ####  The TrainedModel is a template, which can be found in nnfabrik.template.py

# %% [markdown]
# the trained model table is taking care of model training, and stores the model state in a part table. For further analyses of the trained model, one can either overwrite the TrainedModel definition by inheriting from the Base template class, or by attaching other tables to trained model.

# %%
# creating the simples TrainedModel class
@my_nnf.schema
class TrainedModel(TrainedModelBase):
    nnfabrik = my_nnf

# %%
TrainedModel()
# Out:
# *model_fn    *model_hash    *dataset_fn    *dataset_hash  *trainer_fn    *trainer_hash  *seed    comment     score     output     fabrikant_name trainedmodel_t
# +----------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------+ +---------+ +-------+ +--------+ +------------+ +------------+
#
#  (Total: 0)

# %% [markdown]
# as primary keys, it has the hashes of all the configurations, and it stores the score, and the output (which are defined in the respective trainer)

# %% [markdown]
# ## Lets populate

# %% [markdown]
# ## Plot graph of all tables in schema
#
# This is mainly intended as workaround for bug in dj version 0.12.9 and 0.13.0 https://github.com/datajoint/datajoint-python/issues/902

# %%
dj.ERD(schema)

# %%
TrainedModel().populate(display_progress=True)
# Out:
#   0%|                                                                                                                       | 0/1 [00:00<?, ?it/s]
# Epoch 1:   0%|                                                                                                           | 0/3616 [00:00<?, ?it/s]
# Epoch 1:   0%|                                                                                                   | 4/3616 [00:00<01:32, 39.00it/s]
# Epoch 1:   0%|▏                                                                                                  | 9/3616 [00:00<01:31, 39.38it/s]
# Epoch 1:   0%|▍                                                                                                 | 14/3616 [00:00<01:30, 39.84it/s]
# Epoch 1:   0%|▍                                                                                                 | 18/3616 [00:00<01:30, 39.60it/s]
# Epoch 1:   1%|▌                                                                                                 | 23/3616 [00:00<01:28, 40.54it/s]
# Epoch 2:  98%|████████████████████████████████████████████████████████████████████████████████████████████▉  | 3536/3616 [00:32<00:00, 111.67it/s]
# Epoch 2:  98%|█████████████████████████████████████████████████████████████████████████████████████████████▏ | 3548/3616 [00:32<00:00, 112.97it/s]
# Epoch 2:  98%|█████████████████████████████████████████████████████████████████████████████████████████████▌ | 3560/3616 [00:32<00:00, 111.13it/s]
# Epoch 2:  99%|█████████████████████████████████████████████████████████████████████████████████████████████▊ | 3572/3616 [00:32<00:00, 111.13it/s]
# Epoch 2:  99%|██████████████████████████████████████████████████████████████████████████████████████████████▏| 3584/3616 [00:32<00:00, 108.93it/s]
# Epoch 2:  99%|██████████████████████████████████████████████████████████████████████████████████████████████▍| 3596/3616 [00:32<00:00, 112.00it/s]
# Epoch 2: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 3616/3616 [00:32<00:00, 110.01it/s]
# [002|00/05] ---> 0.2606157958507538
# Restoring best model! 0.260616 ---> 0.260616
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:52<00:00, 112.07s/it]

# %%
model_hash = TrainedModel().fetch1("model_hash")

# %%
# now if you want to build the model again, we can use the .load_model() function of the trained model table.
# To use the load model function, the table needs to be restricted to one Entry. 
# for example: restricting with a key:
some_key = dict(model_hash=model_hash)
TrainedModel&some_key
# Out:
# *model_fn      *model_hash    *dataset_fn    *dataset_hash  *trainer_fn    *trainer_hash  *seed    comment        score        output     fabrikant_name trainedmodel_t
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------+ +------------+ +----------+ +--------+ +------------+ +------------+
# nnvision.model a08c72eb297205 nnvision.datas 011a0f520e4393 nnvision.train e225a557fe8039 1000     max_iter: 2.is 0.260616     =BLOB=     mburg          2021-08-25 09:
#  (Total: 1)

# %% [markdown]
# # How to Load a Model

# %%
dataloader, model = (TrainedModel & some_key).load_model()

# %%
# that is the trained model, with the state dict loaded and all. lets set to eval and start using it
model.eval()
# Out:
# Encoder(
#   (core): SE2dCore(
#     (_input_weights_regularizer): LaplaceL2norm(
#       (laplace): Laplace()
#     )
#     (features): Sequential(
#       (layer0): Sequential(
#         (conv): Conv2d(1, 32, kernel_size=(20, 20), stride=(1, 1), bias=False)
#         (norm): BatchNorm2d(32, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (layer1): Sequential(
#         (ds_conv): DepthSeparableConv2d(
#           (in_depth_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (spatial_conv): Conv2d(32, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=32, bias=False)
#           (out_depth_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (norm): BatchNorm2d(32, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (layer2): Sequential(
#         (ds_conv): DepthSeparableConv2d(
#           (in_depth_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (spatial_conv): Conv2d(32, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=32, bias=False)
#           (out_depth_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (norm): BatchNorm2d(32, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#     )
#   ) [SE2dCore regularizers: gamma_input = 11.2|skip = 0]
#
#   (readout): MultipleFullGaussian2d(
#     (3637161140869): isotropic FullGaussian2d (32 x 10 x 10 -> 22) with bias
#     (3638885582960): isotropic FullGaussian2d (32 x 10 x 10 -> 5) with bias
#     (3636034866307): isotropic FullGaussian2d (32 x 10 x 10 -> 20) with bias
#     (3637760318484): isotropic FullGaussian2d (32 x 10 x 10 -> 20) with bias
#     (3631896544452): isotropic FullGaussian2d (32 x 10 x 10 -> 32) with bias
#     (3639749909659): isotropic FullGaussian2d (32 x 10 x 10 -> 8) with bias
#     (3634658447291): isotropic FullGaussian2d (32 x 10 x 10 -> 5) with bias
#     (3638456653849): isotropic FullGaussian2d (32 x 10 x 10 -> 2) with bias
#     (3639492658943): isotropic FullGaussian2d (32 x 10 x 10 -> 17) with bias
#     (3635949043110): isotropic FullGaussian2d (32 x 10 x 10 -> 10) with bias
#     (3639406161189): isotropic FullGaussian2d (32 x 10 x 10 -> 14) with bias
#     (3634055946316): isotropic FullGaussian2d (32 x 10 x 10 -> 21) with bias
#     (3631807112901): isotropic FullGaussian2d (32 x 10 x 10 -> 29) with bias
#     (3635178040531): isotropic FullGaussian2d (32 x 10 x 10 -> 6) with bias
#     (3638802601378): isotropic FullGaussian2d (32 x 10 x 10 -> 7) with bias
#     (3638541006102): isotropic FullGaussian2d (32 x 10 x 10 -> 17) with bias
#     (3640011636703): isotropic FullGaussian2d (32 x 10 x 10 -> 2) with bias
#     (3639664527524): isotropic FullGaussian2d (32 x 10 x 10 -> 18) with bias
#     (3638367026975): isotropic FullGaussian2d (32 x 10 x 10 -> 16) with bias
#     (3638373332053): isotropic FullGaussian2d (32 x 10 x 10 -> 10) with bias
#     (3634744023164): isotropic FullGaussian2d (32 x 10 x 10 -> 12) with bias
#     (3638973674012): isotropic FullGaussian2d (32 x 10 x 10 -> 18) with bias
#     (3632669014376): isotropic FullGaussian2d (32 x 10 x 10 -> 21) with bias
#     (3640095265572): isotropic FullGaussian2d (32 x 10 x 10 -> 25) with bias
#     (3637248451650): isotropic FullGaussian2d (32 x 10 x 10 -> 7) with bias
#     (3639060843972): isotropic FullGaussian2d (32 x 10 x 10 -> 12) with bias
#     (3636552742293): isotropic FullGaussian2d (32 x 10 x 10 -> 24) with bias
#     (3633364677437): isotropic FullGaussian2d (32 x 10 x 10 -> 10) with bias
#     (3637851724731): isotropic FullGaussian2d (32 x 10 x 10 -> 14) with bias
#     (3634142311627): isotropic FullGaussian2d (32 x 10 x 10 -> 14) with bias
#     (3637333931598): isotropic FullGaussian2d (32 x 10 x 10 -> 9) with bias
#     (3632932714885): isotropic FullGaussian2d (32 x 10 x 10 -> 11) with bias
#   )
# )

# %% [markdown]
# # Parameter Extension

# %%
# There's also the parameter extension, so that you can restrict with the confif objects as well.

# %%
from nnfabrik.utility.dj_helpers import create_param_expansion, make_definition
ModelExpanded = create_param_expansion('nnvision.models.se_core_full_gauss_readout', Model,fn_field='model_fn', config_field='model_config')
ModelParams = schema(ModelExpanded)

# %%
ModelParams()
# Out:
# *model_fn    *model_hash    hidden_channel input_kern     hidden_kern    layers     gamma_input    skip     final_nonlinea momentum     pad_input     batch_norm     hidden_dilatio laplace_pa input_regulari init_mu_range  init_sigma     readout_bias   gamma_readout  elu_offset     stack      se_reduction   n_se_blocks    depth_separabl linear     gauss_type     grid_mean_ share_features share_grid     data_info  gamma_grid_dis attention_conv
# +----------+ +------------+ +------------+ +------------+ +------------+ +--------+ +------------+ +------+ +------------+ +----------+ +-----------+ +------------+ +------------+ +--------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +------------+ +------------+ +------------+ +--------+ +------------+ +--------+ +------------+ +------------+ +--------+ +------------+ +------------+
#
#  (Total: 0)

# %%
ModelParams.populate()

# %%
ModelParams()
# Out:
# *model_fn      *model_hash    hidden_channel input_kern     hidden_kern    layers     gamma_input    skip     final_nonlinea momentum     pad_input     batch_norm     hidden_dilatio laplace_pa input_regulari init_mu_range  init_sigma     readout_bias   gamma_readout  elu_offset     stack      se_reduction   n_se_blocks    depth_separabl linear     gauss_type     grid_mean_ share_features share_grid     data_info  gamma_grid_dis attention_conv
# +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +------------+ +------+ +------------+ +----------+ +-----------+ +------------+ +------------+ +--------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +------------+ +------------+ +------------+ +--------+ +------------+ +--------+ +------------+ +------------+ +--------+ +------------+ +------------+
# nnvision.model a08c72eb297205 32             20             5              3          11.2           0        1              0.9          0             1              1              =BLOB=     LaplaceL2norm  0.2            1.0            1              0              0              =BLOB=     32             0              1              0          isotropic      =BLOB=     0              0              =BLOB=     0              0
#  (Total: 1)

# %%
# for example:
TrainedModel*ModelParams&"hidden_kern=5"
# Out:
# *model_fn      *model_hash    *dataset_fn    *dataset_hash  *trainer_fn    *trainer_hash  *seed    comment        score        output     fabrikant_name trainedmodel_t hidden_channel input_kern     hidden_kern    layers     gamma_input    skip     final_nonlinea momentum     pad_input     batch_norm     hidden_dilatio laplace_pa input_regulari init_mu_range  init_sigma     readout_bias   gamma_readout  elu_offset     stack      se_reduction   n_se_blocks    depth_separabl linear     gauss_type     grid_mean_ share_features share_grid     data_info  gamma_grid_dis attention_conv
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------+ +------------+ +----------+ +--------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +------------+ +------+ +------------+ +----------+ +-----------+ +------------+ +------------+ +--------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +------------+ +------------+ +------------+ +--------+ +------------+ +--------+ +------------+ +------------+ +--------+ +------------+ +------------+
# nnvision.model a08c72eb297205 nnvision.datas 011a0f520e4393 nnvision.train e225a557fe8039 1000     max_iter: 2.is 0.260616     =BLOB=     mburg          2021-08-25 09: 32             20             5              3          11.2           0        1              0.9          0             1              1              =BLOB=     LaplaceL2norm  0.2            1.0            1              0              0              =BLOB=     32             0              1              0          isotropic      =BLOB=     0              0              =BLOB=     0              0
#  (Total: 1)

# %%
# Now you can just use that for building the model:
(TrainedModel & (ModelParams & "hidden_kern=5")).load_model()
# Out:
# ({'train': {'3637161140869': <torch.utils.data.dataloader.DataLoader at 0x7fbaeed66a30>,
#    '3638885582960': <torch.utils.data.dataloader.DataLoader at 0x7fbad8bfdbe0>,
#    '3636034866307': <torch.utils.data.dataloader.DataLoader at 0x7fbad8be4fa0>,
#    '3637760318484': <torch.utils.data.dataloader.DataLoader at 0x7fbad8bfb850>,
#    '3631896544452': <torch.utils.data.dataloader.DataLoader at 0x7fbad8bdaeb0>,
#    '3639749909659': <torch.utils.data.dataloader.DataLoader at 0x7fbc170efa00>,
#    '3634658447291': <torch.utils.data.dataloader.DataLoader at 0x7fbad88d65e0>,
#    '3638456653849': <torch.utils.data.dataloader.DataLoader at 0x7fbad88c8160>,
#    '3639492658943': <torch.utils.data.dataloader.DataLoader at 0x7fbad88c8df0>,
#    '3635949043110': <torch.utils.data.dataloader.DataLoader at 0x7fbad88eb9d0>,
#    '3639406161189': <torch.utils.data.dataloader.DataLoader at 0x7fbad88f3580>,
#    '3634055946316': <torch.utils.data.dataloader.DataLoader at 0x7fbad88cc190>,
#    '3631807112901': <torch.utils.data.dataloader.DataLoader at 0x7fbad88cce20>,
#    '3635178040531': <torch.utils.data.dataloader.DataLoader at 0x7fbad88fb9d0>,
#    '3638802601378': <torch.utils.data.dataloader.DataLoader at 0x7fbad88cd580>,
#    '3638541006102': <torch.utils.data.dataloader.DataLoader at 0x7fbad88d2160>,
#    '3640011636703': <torch.utils.data.dataloader.DataLoader at 0x7fbad88d2df0>,
#    '3639664527524': <torch.utils.data.dataloader.DataLoader at 0x7fbad88c6a00>,
#    '3638367026975': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f45580>,
#    '3638373332053': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f74160>,
#    '3634744023164': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f74df0>,
#    '3638973674012': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f729d0>,
#    '3632669014376': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f78790>,
#    '3640095265572': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f4b670>,
#    '3637248451650': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f6b4f0>,
#    '3639060843972': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f663d0>,
#    '3636552742293': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f762b0>,
#    '3633364677437': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f77160>,
#    '3637851724731': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f6c040>,
#    '3634142311627': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f6cfd0>,
#    '3637333931598': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f67eb0>,
#    '3632932714885': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f64d90>},
#   'validation': {'3637161140869': <torch.utils.data.dataloader.DataLoader at 0x7fbb0e69afd0>,
#    '3638885582960': <torch.utils.data.dataloader.DataLoader at 0x7fbad8bd0d00>,
#    '3636034866307': <torch.utils.data.dataloader.DataLoader at 0x7fbad8bcccd0>,
#    '3637760318484': <torch.utils.data.dataloader.DataLoader at 0x7fbad8bfb580>,
#    '3631896544452': <torch.utils.data.dataloader.DataLoader at 0x7fbc170ef1c0>,
#    '3639749909659': <torch.utils.data.dataloader.DataLoader at 0x7fbc170efe20>,
#    '3634658447291': <torch.utils.data.dataloader.DataLoader at 0x7fbad88d6a00>,
#    '3638456653849': <torch.utils.data.dataloader.DataLoader at 0x7fbad88c8580>,
#    '3639492658943': <torch.utils.data.dataloader.DataLoader at 0x7fbad88eb160>,
#    '3635949043110': <torch.utils.data.dataloader.DataLoader at 0x7fbad88ebdf0>,
#    '3639406161189': <torch.utils.data.dataloader.DataLoader at 0x7fbad88f39d0>,
#    '3634055946316': <torch.utils.data.dataloader.DataLoader at 0x7fbad88cc5e0>,
#    '3631807112901': <torch.utils.data.dataloader.DataLoader at 0x7fbad88fb160>,
#    '3635178040531': <torch.utils.data.dataloader.DataLoader at 0x7fbad88fbdf0>,
#    '3638802601378': <torch.utils.data.dataloader.DataLoader at 0x7fbad88cd9d0>,
#    '3638541006102': <torch.utils.data.dataloader.DataLoader at 0x7fbad88d2580>,
#    '3640011636703': <torch.utils.data.dataloader.DataLoader at 0x7fbad88c6190>,
#    '3639664527524': <torch.utils.data.dataloader.DataLoader at 0x7fbad88c6e20>,
#    '3638367026975': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f459d0>,
#    '3638373332053': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f74580>,
#    '3634744023164': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f72160>,
#    '3638973674012': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f72f40>,
#    '3632669014376': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f78df0>,
#    '3640095265572': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f4bcd0>,
#    '3637248451650': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f6bb50>,
#    '3639060843972': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f66a30>,
#    '3636552742293': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f76910>,
#    '3633364677437': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f777c0>,
#    '3637851724731': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f6c6a0>,
#    '3634142311627': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f67580>,
#    '3637333931598': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f64460>,
#    '3632932714885': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f62340>},
#   'test': {'3637161140869': <torch.utils.data.dataloader.DataLoader at 0x7fbad8bfd0a0>,
#    '3638885582960': <torch.utils.data.dataloader.DataLoader at 0x7fbad8be4550>,
#    '3636034866307': <torch.utils.data.dataloader.DataLoader at 0x7fbad8bda610>,
#    '3637760318484': <torch.utils.data.dataloader.DataLoader at 0x7fbad8bda4c0>,
#    '3631896544452': <torch.utils.data.dataloader.DataLoader at 0x7fbc170ef940>,
#    '3639749909659': <torch.utils.data.dataloader.DataLoader at 0x7fbad88d64f0>,
#    '3634658447291': <torch.utils.data.dataloader.DataLoader at 0x7fbad88c80d0>,
#    '3638456653849': <torch.utils.data.dataloader.DataLoader at 0x7fbad88c8d00>,
#    '3639492658943': <torch.utils.data.dataloader.DataLoader at 0x7fbad88eb8e0>,
#    '3635949043110': <torch.utils.data.dataloader.DataLoader at 0x7fbad88f3490>,
#    '3639406161189': <torch.utils.data.dataloader.DataLoader at 0x7fbad88cc0a0>,
#    '3634055946316': <torch.utils.data.dataloader.DataLoader at 0x7fbad88ccd60>,
#    '3631807112901': <torch.utils.data.dataloader.DataLoader at 0x7fbad88fb8e0>,
#    '3635178040531': <torch.utils.data.dataloader.DataLoader at 0x7fbad88cd490>,
#    '3638802601378': <torch.utils.data.dataloader.DataLoader at 0x7fbad88d20d0>,
#    '3638541006102': <torch.utils.data.dataloader.DataLoader at 0x7fbad88d2d00>,
#    '3640011636703': <torch.utils.data.dataloader.DataLoader at 0x7fbad88c6910>,
#    '3639664527524': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f45490>,
#    '3638367026975': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f740d0>,
#    '3638373332053': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f74d00>,
#    '3634744023164': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f728e0>,
#    '3638973674012': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f78610>,
#    '3632669014376': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f4b4f0>,
#    '3640095265572': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f6b370>,
#    '3637248451650': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f66250>,
#    '3639060843972': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f76130>,
#    '3636552742293': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f77040>,
#    '3633364677437': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f77f40>,
#    '3637851724731': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f6ce20>,
#    '3634142311627': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f67d00>,
#    '3637333931598': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f64be0>,
#    '3632932714885': <torch.utils.data.dataloader.DataLoader at 0x7fbad8f62ac0>}},
#  Encoder(
#    (core): SE2dCore(
#      (_input_weights_regularizer): LaplaceL2norm(
#        (laplace): Laplace()
#      )
#      (features): Sequential(
#        (layer0): Sequential(
#          (conv): Conv2d(1, 32, kernel_size=(20, 20), stride=(1, 1), bias=False)
#          (norm): BatchNorm2d(32, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#          (nonlin): ELU(alpha=1.0, inplace=True)
#        )
#        (layer1): Sequential(
#          (ds_conv): DepthSeparableConv2d(
#            (in_depth_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (spatial_conv): Conv2d(32, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=32, bias=False)
#            (out_depth_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          )
#          (norm): BatchNorm2d(32, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#          (nonlin): ELU(alpha=1.0, inplace=True)
#        )
#        (layer2): Sequential(
#          (ds_conv): DepthSeparableConv2d(
#            (in_depth_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (spatial_conv): Conv2d(32, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=32, bias=False)
#            (out_depth_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          )
#          (norm): BatchNorm2d(32, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#          (nonlin): ELU(alpha=1.0, inplace=True)
#        )
#      )
#    ) [SE2dCore regularizers: gamma_input = 11.2|skip = 0]
#
#    (readout): MultipleFullGaussian2d(
#      (3637161140869): isotropic FullGaussian2d (32 x 10 x 10 -> 22) with bias
#      (3638885582960): isotropic FullGaussian2d (32 x 10 x 10 -> 5) with bias
#      (3636034866307): isotropic FullGaussian2d (32 x 10 x 10 -> 20) with bias
#      (3637760318484): isotropic FullGaussian2d (32 x 10 x 10 -> 20) with bias
#      (3631896544452): isotropic FullGaussian2d (32 x 10 x 10 -> 32) with bias
#      (3639749909659): isotropic FullGaussian2d (32 x 10 x 10 -> 8) with bias
#      (3634658447291): isotropic FullGaussian2d (32 x 10 x 10 -> 5) with bias
#      (3638456653849): isotropic FullGaussian2d (32 x 10 x 10 -> 2) with bias
#      (3639492658943): isotropic FullGaussian2d (32 x 10 x 10 -> 17) with bias
#      (3635949043110): isotropic FullGaussian2d (32 x 10 x 10 -> 10) with bias
#      (3639406161189): isotropic FullGaussian2d (32 x 10 x 10 -> 14) with bias
#      (3634055946316): isotropic FullGaussian2d (32 x 10 x 10 -> 21) with bias
#      (3631807112901): isotropic FullGaussian2d (32 x 10 x 10 -> 29) with bias
#      (3635178040531): isotropic FullGaussian2d (32 x 10 x 10 -> 6) with bias
#      (3638802601378): isotropic FullGaussian2d (32 x 10 x 10 -> 7) with bias
#      (3638541006102): isotropic FullGaussian2d (32 x 10 x 10 -> 17) with bias
#      (3640011636703): isotropic FullGaussian2d (32 x 10 x 10 -> 2) with bias
#      (3639664527524): isotropic FullGaussian2d (32 x 10 x 10 -> 18) with bias
#      (3638367026975): isotropic FullGaussian2d (32 x 10 x 10 -> 16) with bias
#      (3638373332053): isotropic FullGaussian2d (32 x 10 x 10 -> 10) with bias
#      (3634744023164): isotropic FullGaussian2d (32 x 10 x 10 -> 12) with bias
#      (3638973674012): isotropic FullGaussian2d (32 x 10 x 10 -> 18) with bias
#      (3632669014376): isotropic FullGaussian2d (32 x 10 x 10 -> 21) with bias
#      (3640095265572): isotropic FullGaussian2d (32 x 10 x 10 -> 25) with bias
#      (3637248451650): isotropic FullGaussian2d (32 x 10 x 10 -> 7) with bias
#      (3639060843972): isotropic FullGaussian2d (32 x 10 x 10 -> 12) with bias
#      (3636552742293): isotropic FullGaussian2d (32 x 10 x 10 -> 24) with bias
#      (3633364677437): isotropic FullGaussian2d (32 x 10 x 10 -> 10) with bias
#      (3637851724731): isotropic FullGaussian2d (32 x 10 x 10 -> 14) with bias
#      (3634142311627): isotropic FullGaussian2d (32 x 10 x 10 -> 14) with bias
#      (3637333931598): isotropic FullGaussian2d (32 x 10 x 10 -> 9) with bias
#      (3632932714885): isotropic FullGaussian2d (32 x 10 x 10 -> 11) with bias
#    )
#  ))
